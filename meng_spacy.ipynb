# %%
import numpy as np 
import pandas as pd 
import spacy
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
import pickle

# %% [markdown]
# # Read file and change the representation of keywords from dict frenquency to a matrix can be analysed by CountVectorizer

# %%
mydata = pd.read_csv('./train.csv')
mydata.head()
# Out:
#    ID                                           keywords  age sex
# 0   1  fibre:16;quoi:1;dangers:1;combien:1;hightech:1...   62   F
# 1   2                     restaurant:1;marrakech.shtml:1   35   M
# 2   3  payer:1;faq:1;taxe:1;habitation:1;macron:1;qui...   45   F
# 3   4  rigaud:3;laurent:3;photo:11;profile:8;photopro...   46   F
# 4   5  societe:1;disparition:1;proche:1;m%c3%a9lanie....   42   F

# %%
df = mydata.copy()
df_nona = df.dropna().reset_index(drop = True)
df_nona.shape
# Out:
# (6418659, 4)

# %%
df_nona['nbr_words'] = df_nona['keywords'].apply(lambda x : x.count(";"))

# %%
droprows = df_nona[df_nona['nbr_words'] < 50].index
df_nona = df_nona.drop(droprows).reset_index(drop = True)

# %%
def listToDict(lst):
    '''
    convert a list to dictionary
    e.g. 'restaurant:1;marrakech.shtml:1' --> {'restaurant:1, marrakech.shtml:1}
    
    '''
    op = {lst[i]: lst[i + 1] for i in range(0, len(lst), 2)}

    return op

def real_sent(input_dict):
    '''
    combine the word with frequency to one element 
    '''
    sent = ''
    for word in input_dict:
        sent = sent + (word +' ') * input_dict[word]
    return sent

def token(data):
    '''
    from word with frequency to a complete piece 
    e.g. 'restaurant:1;marrakech.shtml:1' --> restaurant marrakech.shtml
    '''

    target = []
    for element in data:
        # split the word frequency 
        element = element.replace(';', ':')
        element = element.split(':')
        
        # skip the Indexerror 
        try:
            the_dict = listToDict(element)
        except IndexError:
            pass
        
        # final data
        for key in the_dict:
            the_dict[key] = int(the_dict[key])
        target.append(real_sent(the_dict))   
    return target

# %%
df = df_nona.iloc[:10000,:]
tokens = token(df.keywords)
df['text'] = pd.DataFrame(tokens)
df['text'] = df['text'].apply(lambda x : x.replace('é','e'))
# Out:
# <ipython-input-7-9e892b2b1fdb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = pd.DataFrame(tokens)
# <ipython-input-7-9e892b2b1fdb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(lambda x : x.replace('é','e'))

# %%
df
# Out:
#           ID                                           keywords  age sex  \
# 0          1  fibre:16;quoi:1;dangers:1;combien:1;hightech:1...   62   F
# 1         24  tabac:1;les:1;terrorisme:1;excuses:2;luxe:2;do...   40   M
# 2         28  lively:1;messi:1;enzo:1;nolwenn:1;diaz:1;kourt...   50   F
# 3         33  adams:1;refaeli:1;paltrow:1;brodier:2;ariane:2...   52   F
# 4         42  service:1;siege:1;avenue:1;douleur+a+la+poitri...   62   F
# ...      ...                                                ...  ...  ..
# 9995  170024  delon:1;sardou:2;loup:1;sur:1;bernard:1;martin...   34   F
# 9996  170058  pierre:2;chazal:1;chazel:1;photos:33;loup:1;br...   43   F
# 9997  170073  sortir:22;terrain:1;enflamme:1;avec:1;pratique...   56   M
# 9998  170079  lavoine:1;arcady:1;saluer:1;hossein:1;chazel:1...   28   M
# 9999  170097  banque:1;sont:1;une:1;trouve:1;week:1;former:1...   64   M
#
#       nbr_words                                               text
# 0            57  fibre fibre fibre fibre fibre fibre fibre fibr...
# 1            68  tabac les terrorisme excuses excuses luxe luxe...
# 2           111  lively messi enzo nolwenn diaz kourtney beckha...
# 3           230  adams refaeli paltrow brodier brodier ariane a...
# 4           155  service siege avenue douleur+a+la+poitrine+cot...
# ...         ...                                                ...
# 9995         67  delon sardou sardou loup sur bernard martin pa...
# 9996         69  pierre pierre chazal chazel photos photos phot...
# 9997         64  sortir sortir sortir sortir sortir sortir sort...
# 9998         72  lavoine arcady saluer hossein chazel robert so...
# 9999         75  banque sont une trouve week former les ont pas...
#
# [10000 rows x 6 columns]

# %% [markdown]
# # clean the text to proper text by lemmatizer and tokenize and remove the meaningless words

# %%
#removes stopwords, numbers, meaningless words
nlp = spacy.load('fr_core_news_md')

# %%
def clean_my_text(data, col1):
    def cleanline(k):
        doc = nlp(k)
        mystr = ''
        for token in doc:
            if token.is_alpha and token.has_vector and (not token.is_stop):
                mystr += token.lemma_.replace('é','e') + ' '
        return mystr
    kk = data[col1].apply(lambda x:cleanline(x))
    mydff = pd.DataFrame(kk)
    return mydff

# %%
df_test = df
df_test['token_clean'] = clean_my_text(df_test, 'text')
df_test.shape
# Out:
# <ipython-input-11-4dce1aabc898>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['token_clean'] = clean_my_text(df_test, 'text')
# (10000, 7)

# %%
df_test
# Out:
#           ID                                           keywords  age sex  \
# 0          1  fibre:16;quoi:1;dangers:1;combien:1;hightech:1...   62   F
# 1         24  tabac:1;les:1;terrorisme:1;excuses:2;luxe:2;do...   40   M
# 2         28  lively:1;messi:1;enzo:1;nolwenn:1;diaz:1;kourt...   50   F
# 3         33  adams:1;refaeli:1;paltrow:1;brodier:2;ariane:2...   52   F
# 4         42  service:1;siege:1;avenue:1;douleur+a+la+poitri...   62   F
# ...      ...                                                ...  ...  ..
# 9995  170024  delon:1;sardou:2;loup:1;sur:1;bernard:1;martin...   34   F
# 9996  170058  pierre:2;chazal:1;chazel:1;photos:33;loup:1;br...   43   F
# 9997  170073  sortir:22;terrain:1;enflamme:1;avec:1;pratique...   56   M
# 9998  170079  lavoine:1;arcady:1;saluer:1;hossein:1;chazel:1...   28   M
# 9999  170097  banque:1;sont:1;une:1;trouve:1;week:1;former:1...   64   M
#
#       nbr_words                                               text  \
# 0            57  fibre fibre fibre fibre fibre fibre fibre fibr...
# 1            68  tabac les terrorisme excuses excuses luxe luxe...
# 2           111  lively messi enzo nolwenn diaz kourtney beckha...
# 3           230  adams refaeli paltrow brodier brodier ariane a...
# 4           155  service siege avenue douleur+a+la+poitrine+cot...
# ...         ...                                                ...
# 9995         67  delon sardou sardou loup sur bernard martin pa...
# 9996         69  pierre pierre chazal chazel photos photos phot...
# 9997         64  sortir sortir sortir sortir sortir sortir sort...
# 9998         72  lavoine arcady saluer hossein chazel robert so...
# 9999         75  banque sont une trouve week former les ont pas...
#
#                                             token_clean
# 0     fibre fibre fibr fibr fibr fibr fibr fibr fibr...
# 1     tabac terrorisme excuse excuse lux lux dollar ...
# 2     lively messi end end end end end end end end e...
# 3     ariane ariane victoria tobe chanson fete fet f...
# 4     service siege avenue gerard transfert historiq...
# ...                                                 ...
# 9995  loup bernard martin pascal pascal lang journal...
# 9996  pierre pierre photo photo photo photo photo ph...
# 9997  sortir sortir sortir sortir sortir sortir sort...
# 9998  saluer robert bernard pascal pascal mari mari ...
# 9999  banque trouve week former exce flash actu cons...
#
# [10000 rows x 7 columns]

# %% [markdown]
# # TfidfVectorizer and train models

# %%
#split training and test set
Y = df_test[["sex","age"]]
X_train_pre, X_test_pre, y_train, y_test = train_test_split(df_test.token_clean, Y, test_size=0.2, random_state=66)
tfidf = TfidfVectorizer(min_df=0.01)
tfidffit = tfidf.fit(X_train_pre)
X_train = tfidffit.transform(X_train_pre)
#Dump file
pickle.dump(tfidffit, open("tfidf1.pkl", "wb"))
mycv = pickle.load(open("tfidf1.pkl", 'rb'))
cv_test = TfidfVectorizer(vocabulary = mycv.vocabulary_)
cv_test_fit = cv_test.fit(X_test_pre)
X_test = cv_test.transform(X_test_pre)

# %%
df_test
# Out:
#           ID                                           keywords  age sex  \
# 0          1  fibre:16;quoi:1;dangers:1;combien:1;hightech:1...   62   F
# 1         24  tabac:1;les:1;terrorisme:1;excuses:2;luxe:2;do...   40   M
# 2         28  lively:1;messi:1;enzo:1;nolwenn:1;diaz:1;kourt...   50   F
# 3         33  adams:1;refaeli:1;paltrow:1;brodier:2;ariane:2...   52   F
# 4         42  service:1;siege:1;avenue:1;douleur+a+la+poitri...   62   F
# ...      ...                                                ...  ...  ..
# 9995  170024  delon:1;sardou:2;loup:1;sur:1;bernard:1;martin...   34   F
# 9996  170058  pierre:2;chazal:1;chazel:1;photos:33;loup:1;br...   43   F
# 9997  170073  sortir:22;terrain:1;enflamme:1;avec:1;pratique...   56   M
# 9998  170079  lavoine:1;arcady:1;saluer:1;hossein:1;chazel:1...   28   M
# 9999  170097  banque:1;sont:1;une:1;trouve:1;week:1;former:1...   64   M
#
#       nbr_words                                               text  \
# 0            57  fibre fibre fibre fibre fibre fibre fibre fibr...
# 1            68  tabac les terrorisme excuses excuses luxe luxe...
# 2           111  lively messi enzo nolwenn diaz kourtney beckha...
# 3           230  adams refaeli paltrow brodier brodier ariane a...
# 4           155  service siege avenue douleur+a+la+poitrine+cot...
# ...         ...                                                ...
# 9995         67  delon sardou sardou loup sur bernard martin pa...
# 9996         69  pierre pierre chazal chazel photos photos phot...
# 9997         64  sortir sortir sortir sortir sortir sortir sort...
# 9998         72  lavoine arcady saluer hossein chazel robert so...
# 9999         75  banque sont une trouve week former les ont pas...
#
#                                             token_clean
# 0     fibre fibre fibr fibr fibr fibr fibr fibr fibr...
# 1     tabac terrorisme excuse excuse lux lux dollar ...
# 2     lively messi end end end end end end end end e...
# 3     ariane ariane victoria tobe chanson fete fet f...
# 4     service siege avenue gerard transfert historiq...
# ...                                                 ...
# 9995  loup bernard martin pascal pascal lang journal...
# 9996  pierre pierre photo photo photo photo photo ph...
# 9997  sortir sortir sortir sortir sortir sortir sort...
# 9998  saluer robert bernard pascal pascal mari mari ...
# 9999  banque trouve week former exce flash actu cons...
#
# [10000 rows x 7 columns]

# %%
tfidf.get_feature_names()
# Out:
# ['abandonnee',
#  'abonnement',
#  'abonner',
#  'abord',
#  'absence',
#  'accident',
#  'achat',
#  'acteur',
#  'action',
#  'actu',
#  'actualit',
#  'actualite',
#  'actualiter',
#  'actualites',
#  'adepte',
#  'adsl',
#  'advocaat',
#  'affaire',
#  'affirment',
#  'afp',
#  'age',
#  'agent',
#  'agresse',
#  'agression',
#  'aid',
#  'aide',
#  'air',
#  'aire',
#  'alain',
#  'alcool',
#  'alerte',
#  'alexandra',
#  'alexandre',
#  'alexandrer',
#  'aliment',
#  'alliance',
#  'alsace',
#  'ambitieux',
#  'amelie',
#  'americain',
#  'ami',
#  'amincir',
#  'amour',
#  'amoureux',
#  'an',
#  'anatomy',
#  'ancien',
#  'and',
#  'anderson',
#  'ang',
#  'angelique',
#  'animal',
#  'ann',
#  'anne',
#  'annee',
#  'annonce',
#  'annoncer',
#  'annulation',
#  'anti',
#  'antiraciste',
#  'antoin',
#  'antoine',
#  'aout',
#  'apl',
#  'appartement',
#  'apple',
#  'approuve',
#  'arabie',
#  'argent',
#  'argentin',
#  'ariane',
#  'armee',
#  'arnaque',
#  'arras',
#  'art',
#  'article',
#  'artisans',
#  'artu',
#  'artus',
#  'assassinat',
#  'association',
#  'assuranc',
#  'assurance',
#  'astuce',
#  'athletisme',
#  'atlantique',
#  'attaqu',
#  'attaque',
#  'atteinte',
#  'attentat',
#  'aude',
#  'audi',
#  'autant',
#  'auto',
#  'automne',
#  'automobile',
#  'autoriser',
#  'auvergne',
#  'avance',
#  'avenue',
#  'avril',
#  'ayem',
#  'baby',
#  'bac',
#  'bachelier',
#  'bain',
#  'baiss',
#  'baisse',
#  'balade',
#  'ballerine',
#  'banqu',
#  'banque',
#  'bar',
#  'barca',
#  'bardot',
#  'bareme',
#  'barre',
#  'bassin',
#  'beaut',
#  'beaute',
#  'bebe',
#  'bel',
#  'bella',
#  'benjamin',
#  'benoit',
#  'bernard',
#  'bete',
#  'bier',
#  'biere',
#  'biscuit',
#  'blake',
#  'blanc',
#  'blanche',
#  'bleu',
#  'bleus',
#  'bloque',
#  'bmw',
#  'bobo',
#  'boire',
#  'bois',
#  'bol',
#  'bon',
#  'bonbonn',
#  'bonbonne',
#  'bordeaux',
#  'bosse',
#  'boucle',
#  'boulevard',
#  'bourgogne',
#  'bouton',
#  'box',
#  'boxe',
#  'brader',
#  'bretagne',
#  'bricolage',
#  'brigitte',
#  'bruni',
#  'budget',
#  'bureau',
#  'business',
#  'but',
#  'cabl',
#  'cable',
#  'cac',
#  'cadre',
#  'caisse',
#  'cake',
#  'calcul',
#  'calendrier',
#  'caline',
#  'cambrure',
#  'cameron',
#  'camille',
#  'canape',
#  'cancer',
#  'candidat',
#  'capitaine',
#  'carbonade',
#  'cardinal',
#  'cardinale',
#  'carl',
#  'carla',
#  'carler',
#  'carre',
#  'cartabl',
#  'cartable',
#  'carte',
#  'casque',
#  'casta',
#  'cause',
#  'cayenn',
#  'cayenne',
#  'ceinture',
#  'censur',
#  'censure',
#  'centre',
#  'cerf',
#  'cerise',
#  'cerrada',
#  'cgt',
#  'chagrin',
#  'chaine',
#  'chambre',
#  'champagne',
#  'champion',
#  'change',
#  'changement',
#  'changer',
#  'chanson',
#  'charge',
#  'charles',
#  'charm',
#  'chasse',
#  'chasser',
#  'chateau',
#  'chaussure',
#  'chauvin',
#  'chef',
#  'cheque',
#  'cherche',
#  'chercher',
#  'chercheur',
#  'cheveux',
#  'chic',
#  'chien',
#  'chiffre',
#  'chinois',
#  'chloe',
#  'choc',
#  'chocolat',
#  'choisir',
#  'chomage',
#  'christina',
#  'chute',
#  'cibl',
#  'cible',
#  'ciel',
#  'cimetiere',
#  'cinema',
#  'citation',
#  'civil',
#  'clair',
#  'classe',
#  'classement',
#  'claudia',
#  'claudier',
#  'client',
#  'climatique',
#  'clint',
#  'club',
#  'coco',
#  'code',
#  'coeur',
#  'cole',
#  'collection',
#  'college',
#  'com',
#  'combat',
#  'combattant',
#  'commerce',
#  'commercial',
#  'complot',
#  'composant',
#  'compote',
#  'compte',
#  'concerne',
#  'condition',
#  'conduire',
#  'confidence',
#  'confient',
#  'confier',
#  'conflit',
#  'cong',
#  'conge',
#  'conjoncture',
#  'connaitre',
#  'connaître',
#  'conner',
#  'connexion',
#  'conseil',
#  'conseils',
#  'conso',
#  'construction',
#  'consulat',
#  'contenir',
#  'content',
#  'contrat',
#  'controle',
#  'copain',
#  'corp',
#  'corps',
#  'cote',
#  'country',
#  'coup',
#  'coupe',
#  'coupl',
#  'couple',
#  'cour',
#  'court',
#  'cout',
#  'coute',
#  'crem',
#  'creme',
#  'crepes',
#  'crev',
#  'creve',
#  'cuber',
#  'cuisine',
#  'culpabilite',
#  'culture',
#  'cur',
#  'curry',
#  'dame',
#  'danger',
#  'dani',
#  'daphne',
#  'date',
#  'davant',
#  'daver',
#  'david',
#  'debat',
#  'debit',
#  'dece',
#  'deception',
#  'deco',
#  'defaut',
#  'definition',
#  'demande',
#  'demi',
#  'demission',
#  'demonstration',
#  'denis',
#  'dent',
#  'depart',
#  'depeche',
#  'depute',
#  'descente',
#  'design',
#  'dessert',
#  'detail',
#  'deuxiem',
#  'deuxieme',
#  'devenir',
#  'devient',
#  'devoir',
#  'diana',
#  'dianer',
#  'diaporama',
#  'dictionnair',
#  'dictionnaire',
#  'difference',
#  'differences',
#  'diffusion',
#  'dignite',
#  'dion',
#  'diplomate',
#  'dire',
#  'direct',
#  'dis',
#  'discuter',
#  'disparition',
#  'dollar',
#  'donne',
#  'donner',
#  'dos',
#  'dossier',
#  'douleur',
#  'doux',
#  'download',
#  'droit',
#  'droite',
#  'dune',
#  'duo',
#  'duree',
#  'dynamiter',
#  'eau',
#  'ecarter',
#  'eco',
#  'ecole',
#  'economie',
#  'economiser',
#  'ecran',
#  'editorial',
#  'effectue',
#  'effet',
#  'elu',
#  'emily',
#  'empare',
#  'emploi',
#  'emporte',
#  'enceint',
#  'end',
#  'endive',
#  'endives',
#  'enfant',
#  'enfer',
#  'enflamme',
#  'engagee',
#  'enlevement',
#  'enquet',
#  'enquete',
#  'entreprise',
#  'entretien',
#  'envergure',
#  'envoyes',
#  'epice',
#  'equipe',
#  'escalope',
#  'escapade',
#  'escarpin',
#  'espac',
#  'espace',
#  'estelle',
#  'etablissement',
#  'etage',
#  'etages',
#  'etat',
#  'ete',
#  'eternelle',
#  'etienn',
#  'etranger',
#  'etre',
#  'etudiant',
#  'etudier',
#  'euro',
#  'europe',
#  'evenement',
#  'examen',
#  'excuse',
#  'existe',
#  'explosifs',
#  'exposition',
#  'expression',
#  'extrait',
#  'fac',
#  'face',
#  'facebook',
#  'facon',
#  'fair',
#  'faire',
#  'falloir',
#  'familial',
#  'famille',
#  'faq',
#  'fatal',
#  'fauteuil',
#  'favorable',
#  'feminine',
#  'femme',
#  'femmes',
#  'ferme',
#  'ferrari',
#  'ferri',
#  'fet',
#  'fete',
#  'fibr',
#  'fibre',
#  'fiche',
#  'figaro',
#  'fil',
#  'filet',
#  'fille',
#  'film',
#  'filme',
#  'fin',
#  'finance',
#  'financier',
#  'finir',
#  'fixe',
#  'flamande',
#  'flash',
#  'fleur',
#  'foie',
#  'fois',
#  'folie',
#  'folle',
#  'fondre',
#  'foot',
#  'football',
#  'foret',
#  'formation',
#  'former',
#  'formule',
#  'forum',
#  'fox',
#  'frais',
#  'fraise',
#  'francai',
#  'francais',
#  'francaise',
#  'france',
#  'francfort',
#  'francis',
#  'francisco',
#  'francoi',
#  'francois',
#  'frappe',
#  'fromage',
#  'fruit',
#  'fumee',
#  'fumer',
#  'gagnant',
#  'gagne',
#  'gang',
#  'gard',
#  'garde',
#  'gastronomie',
#  'gateau',
#  'gauche',
#  'gaufre',
#  'gaz',
#  'gendarme',
#  'general',
#  'genre',
#  'george',
#  'gerard',
#  'germain',
#  'geste',
#  'ghibli',
#  'glamour',
#  'golf',
#  'google',
#  'gouvernement',
#  'grand',
#  'gras',
#  'gratuit',
#  'grave',
#  'grey',
#  'griffe',
#  'gros',
#  'grossesse',
#  'groupe',
#  'guerre',
#  'guid',
#  'guillaume',
#  'guy',
#  'haddock',
#  'hamon',
#  'harry',
#  'harvey',
#  'hausse',
#  'haut',
#  'helene',
#  'henri',
#  'heritage',
#  'heros',
#  'heure',
#  'heureux',
#  'hidalgo',
#  'high',
#  'hilton',
#  'histoire',
#  'historique',
#  'hiver',
#  'hollande',
#  'home',
#  'homm',
#  'hommage',
#  'homme',
#  'horoscope',
#  'hotel',
#  'houston',
#  'humain',
#  'idee',
#  'idiot',
#  'ifa',
#  'ile',
#  'image',
#  'immediate',
#  'immobilier',
#  'impot',
#  'impression',
#  'incroyable',
#  'inculpation',
#  'indication',
#  'indice',
#  'indigo',
#  'info',
#  'information',
#  'ingrid',
#  'inhabituel',
#  'insignia',
#  'installation',
#  'instaurer',
#  'interdiction',
#  'interieur',
#  'international',
#  'internet',
#  'interpelle',
#  'interview',
#  'invitation',
#  'invite',
#  'iphon',
#  'iphone',
#  'iri',
#  'iris',
#  'jack',
#  'jackson',
#  'jacques',
#  'jambon',
#  'jardin',
#  'jason',
#  'jean',
#  'jesse',
#  'jet',
#  'jeu',
#  'jeune',
#  'jobs',
#  'johnny',
#  'joie',
#  'joli',
#  'jong',
#  'jouer',
#  'jour',
#  'journal',
#  'judiciaire',
#  'judo',
#  'julie',
#  'jupe',
#  'justin',
#  'kate',
#  'kebir',
#  'kelly',
#  'kentucky',
#  'kev',
#  'kia',
#  'kim',
#  'koh',
#  'kona',
#  'lady',
#  'laetitia',
#  'lait',
#  'lancer',
#  'land',
#  'lang',
#  'langue',
#  'lanta',
#  'lapidation',
#  'laurent',
#  'legumes',
#  'leila',
#  'leonardo',
#  'lettre',
#  'liberal',
#  'libre',
#  'licence',
#  'ligne',
#  'ligue',
#  'lille',
#  'lily',
#  'linternaute',
#  'lio',
#  'lionel',
#  'liste',
#  'lit',
#  'live',
#  'lively',
#  'livre',
#  'locatair',
#  'locataire',
#  'location',
#  'logement',
#  'loi',
#  'loisir',
#  'long',
#  'looks',
#  'loup',
#  'lourd',
#  'luc',
#  'lux',
#  'luxe',
#  'lycee',
#  'lynx',
#  'macaron',
#  'macron',
#  'madelein',
#  'madeleines',
#  'madonna',
#  'magazine',
#  'mail',
#  'main',
#  'mairie',
#  'maison',
#  'majorite',
#  'mal',
#  'maladie',
#  'maman',
#  'management',
#  'manger',
#  'manifester',
#  'mannequin',
#  'marc',
#  'marche',
#  'mari',
#  'mariage',
#  'marie',
#  'marier',
#  'marin',
#  'marine',
#  'mark',
#  'marne',
#  'maroc',
#  'maroilles',
#  'marseille',
#  'martin',
#  'match',
#  'mauvais',
#  'maximum',
#  'media',
#  'medias',
#  'medicament',
#  'mediterrane',
#  'mediterranee',
#  'megane',
#  'meilleur',
#  'mel',
#  'melania',
#  'memoir',
#  'memoire',
#  'menace',
#  'menacer',
#  'mention',
#  'mer',
#  'mercato',
#  'mercede',
#  'mercedes',
#  'message',
#  'messi',
#  'mesure',
#  'meteo',
#  'method',
#  'methode',
#  'mettre',
#  'michael',
#  'michel',
#  'midi',
#  'mieux',
#  'mignon',
#  'migrant',
#  'militant',
#  'milliard',
#  'millier',
#  'million',
#  'mimolette',
#  'mini',
#  'mobile',
#  'mocassin',
#  'mode',
#  'modele',
#  'mois',
#  'monde',
#  'mondial',
#  'monsieur',
#  'montant',
#  'mort',
#  'mostra',
#  'mot',
#  'moteur',
#  'moto',
#  'moule',
#  'moules',
#  'mourir',
#  'moutarde',
#  'mouton',
#  'mule',
#  'musiqu',
#  'mutation',
#  'mythe',
#  'nature',
#  'naturiste',
#  'negatif',
#  'negociation',
#  'nemo',
#  'net',
#  'netflix',
#  'news',
#  'nice',
#  'nicolas',
#  'nicole',
#  'noeud',
#  'noir',
#  'noix',
#  'nord',
#  'normandie',
#  'note',
#  'nour',
#  'nouveau',
#  'numero',
#  'obligatoire',
#  'obliger',
#  'obseque',
#  'oeil',
#  'oeuf',
#  'officiel',
#  'offrir',
#  'olivier',
#  'one',
#  'open',
#  'operateur',
#  'orange',
#  'ordonnance',
#  'ordonnancer',
#  'ordonnances',
#  'oreille',
#  'ours',
#  'ouvrir',
#  'paiement',
#  'pain',
#  'paix',
#  'pamplemousse',
#  'pantalon',
#  'pape',
#  'papier',
#  'parade',
#  'paradi',
#  'paradis',
#  'parfaire',
#  'parfait',
#  'paris',
#  'parlementaire',
#  'parmentier',
#  'partir',
#  'pascal',
#  'passer',
#  'pate',
#  'patrimoin',
#  'patrimoine',
#  'paul',
#  'payer',
#  'pays',
#  'pen',
#  'people',
#  'per',
#  'perdre',
#  'personne',
#  'personnel',
#  'perte',
#  'pester',
#  'petit',
#  'phantom',
#  'philip',
#  'philippe',
#  'photo',
#  'piece',
#  'pied',
#  'pierre',
#  'pilule',
#  'piscine',
#  'place',
#  'placement',
#  'placer',
#  'plafond',
#  'plage',
#  'plan',
#  'plaquer',
#  'play',
#  'plaza',
#  'plutot',
#  'point',
#  'poireal',
#  'poireau',
#  'pois',
#  'poisson',
#  'police',
#  'politique',
#  'polo',
#  'polyvalent',
#  'pomme',
#  'pont',
#  'pop',
#  'porc',
#  'porsch',
#  'port',
#  'portable',
#  'porte',
#  'porter',
#  'pose',
#  'posologie',
#  'post',
#  'poste',
#  'potentiellement',
#  'potjevleesch',
#  'poulet',
#  'pouvoir',
#  'pratique',
#  'premier',
#  'premiere',
#  'premieres',
#  'premium',
#  'prendre',
#  'prenom',
#  'prenoms',
#  'prepare',
#  'present',
#  'presente',
#  'presidence',
#  'president',
#  'presse',
#  'pret',
#  'prete',
#  'prime',
#  'prince',
#  'princesse',
#  'principal',
#  'prise',
#  'prison',
#  'prix',
#  'probleme',
#  'prochain',
#  'professeur',
#  'professionnel',
#  'profil',
#  'profile',
#  'profit',
#  'programm',
#  'programme',
#  'project',
#  'projet',
#  'propos',
#  'psa',
#  'psychanalyse',
#  'psychologie',
#  'public',
#  'publicite',
#  'pull',
#  'question',
#  'quiche',
#  'quitte',
#  'quotidien',
#  'raisin',
#  'raison',
#  'ras',
#  'rayonnant',
#  'realisateur',
#  'recette',
#  'recevoir',
#  'rechauffement',
#  'recherche',
#  'reclame',
#  'reconcilier',
#  'reconnaissance',
#  'reform',
#  'reforme',
#  'regions',
#  'regle',
#  'regne',
#  'regrette',
#  'reine',
#  'relance',
#  'renault',
#  'rencontre',
#  'rendre',
#  'rentre',
#  'rentree',
#  'reprendre',
#  'republicain',
#  'reseau',
#  'responsable',
#  'ressource',
#  'restaurant',
#  'restaurer',
#  'resultat',
#  'resume',
#  'retire',
#  'retrouve',
#  'retrouver',
#  'reve',
#  'revenir',
#  'revoir',
#  'reynolds',
#  'richard',
#  'risque',
#  'rituel',
#  'rive',
#  'robe',
#  'robert',
#  'roc',
#  'role',
#  'rolls',
#  'romain',
#  'rond',
#  'roquette',
#  'rose',
#  'rouge',
#  'route',
#  'rue',
#  'rugby',
#  'rupture',
#  'russe',
#  'russie',
#  'rutabaga',
#  'ryan',
#  'sable',
#  'sac',
#  'sacre',
#  'saint',
#  'saison',
#  'salad',
#  'salade',
#  'salair',
#  ...]

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train, y_train["sex"].tolist())
y_pred_sex = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(classification_report(y_test["sex"],y_pred_sex))
# Out:
#               precision    recall  f1-score   support
#
#            F       0.78      0.76      0.77      1132
#            M       0.69      0.72      0.71       868
#
#     accuracy                           0.74      2000
#    macro avg       0.74      0.74      0.74      2000
# weighted avg       0.74      0.74      0.74      2000

# %%
df_test.to_csv('mycleandatanew.csv')

# %% [markdown]
# # Age prediction

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbdt = GradientBoostingRegressor()
gbdt.fit(X_train, y_train["age"].tolist())
y_pred_age = gbdt.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test["age"], y_pred_age)
mse
# Out:
# 151.34482142073617

# %%
r2_score(y_test["age"], y_pred_age)
# Out:
# 0.04756171092028538

# %% [markdown]
# # predict and fill up the test.csv file

# %%
df_target = pd.read_csv('test.csv')

# %%
df_target
# Out:
#               ID                                           keywords  age  sex
# 0              1                                                NaN  NaN  NaN
# 1              2  cecilia.gosselin:1;flash:1;ville:1;obseques:1;...  NaN  NaN
# 2              3  p1_1697235:1;peut:1;jcms:1;les:1;acceptees:1;p...  NaN  NaN
# 3              4                                  002lundu83vnndv:1  NaN  NaN
# 4              5  high:3;patisserie:1;apple:3;tech:3;obseques:1;...  NaN  NaN
# ...          ...                                                ...  ...  ...
# 3111780  3111781  frere:1;bien:1;definition:1;7e72:1;sur:3;11e7:...  NaN  NaN
# 3111781  3111782                                                NaN  NaN  NaN
# 3111782  3111783                                                NaN  NaN  NaN
# 3111783  3111784                                                NaN  NaN  NaN
# 3111784  3111785                                                NaN  NaN  NaN
#
# [3111785 rows x 4 columns]

# %%
narows = df_target[df_target['keywords'].isna()].index

# %%
df_target = df_target.drop(narows).reset_index(drop = True)

# %%
test_tokens = token(df_target.keywords)
df_target['text'] = pd.DataFrame(test_tokens)
df_target
# Out:
#               ID                                           keywords  age  sex  \
# 0              2  cecilia.gosselin:1;flash:1;ville:1;obseques:1;...  NaN  NaN
# 1              3  p1_1697235:1;peut:1;jcms:1;les:1;acceptees:1;p...  NaN  NaN
# 2              4                                  002lundu83vnndv:1  NaN  NaN
# 3              5  high:3;patisserie:1;apple:3;tech:3;obseques:1;...  NaN  NaN
# 4              6  disparition:1;vue:1;maelys:1;deuxieme:1;place:...  NaN  NaN
# ...          ...                                                ...  ...  ...
# 2748738  3111777  suspendu:1;medicament:1;nouveau:1;sur:1;actual...  NaN  NaN
# 2748739  3111778  chocolat:1;recettes:1;eclats:1;crepes:1;sucree...  NaN  NaN
# 2748740  3111779  forum:1;changer:1;vrai:1;twitter:1;affich:1;so...  NaN  NaN
# 2748741  3111780  astuce:1;recettes:1;menu:1;gastronomie:1;repas...  NaN  NaN
# 2748742  3111781  frere:1;bien:1;definition:1;7e72:1;sur:3;11e7:...  NaN  NaN
#
#                                                       text
# 0        cecilia.gosselin flash ville obseques economie...
# 1        p1_1697235 peut jcms les acceptees pas benefic...
# 2                                         002lundu83vnndv
# 3        high high high patisserie apple apple apple te...
# 4        disparition vue maelys deuxieme place actu fla...
# ...                                                    ...
# 2748738  suspendu medicament nouveau sur actualite marche
# 2748739  chocolat recettes eclats crepes sucrees pistac...
# 2748740         forum changer vrai twitter affich son nom
# 2748741  astuce recettes menu gastronomie repas tomates...
# 2748742  frere bien definition 7e72 sur 11e7 11e7 inter...
#
# [2748743 rows x 5 columns]

# %%
df_target = df_target[:10000]
df_target['token_clean'] = clean_my_text(df_target, 'text')
# Out:
# <ipython-input-31-82869e2ea539>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target['token_clean'] = clean_my_text(df_target, 'text')

# %%
df_target
# Out:
#          ID                                           keywords  age  sex  \
# 0         2  cecilia.gosselin:1;flash:1;ville:1;obseques:1;...  NaN  NaN
# 1         3  p1_1697235:1;peut:1;jcms:1;les:1;acceptees:1;p...  NaN  NaN
# 2         4                                  002lundu83vnndv:1  NaN  NaN
# 3         5  high:3;patisserie:1;apple:3;tech:3;obseques:1;...  NaN  NaN
# 4         6  disparition:1;vue:1;maelys:1;deuxieme:1;place:...  NaN  NaN
# ...     ...                                                ...  ...  ...
# 9995  11353  faq:2;forum:1;force:1;acompte:2;majeure:1;affi...  NaN  NaN
# 9996  11354             mouhcine:1;garcon:1;prenom:1;prenoms:1  NaN  NaN
# 9997  11355  desprez:1;alain:1;obseques:1;pascal:1;cinema:1...  NaN  NaN
# 9998  11356  utilisateurs:1;mineur:10;gold:10;jeu:10;strike...  NaN  NaN
# 9999  11357                                             jobs:1  NaN  NaN
#
#                                                    text  \
# 0     cecilia.gosselin flash ville obseques economie...
# 1     p1_1697235 peut jcms les acceptees pas benefic...
# 2                                      002lundu83vnndv
# 3     high high high patisserie apple apple apple te...
# 4     disparition vue maelys deuxieme place actu fla...
# ...                                                 ...
# 9995  faq faq forum force acompte acompte majeure af...
# 9996                    mouhcine garcon prenom prenoms
# 9997  desprez alain obseques pascal cinema dans unis...
# 9998  utilisateurs mineur mineur mineur mineur mineu...
# 9999                                              jobs
#
#                                             token_clean
# 0     flash ville obseque economie cinema chagrin un...
# 1                            assurance saisir vie fisc
# 2
# 3     high high high patisserie apple apple apple te...
# 4     disparition vue deuxieme place actu flash gard...
# ...                                                 ...
# 9995  faq faq forum force acompte acompte majeur loc...
# 9996                              garcon prenom prenom
# 9997          alain obseque pascal cinema unis chagrin
# 9998  utilisateur mineur mineur mineur mineur mineur...
# 9999                                              jobs
#
# [10000 rows x 6 columns]

# %%
cv_test = TfidfVectorizer(vocabulary = mycv.vocabulary_)
cv_test_fit = cv_test.fit(df_target['token_clean'])
X_to_pred = cv_test.transform(df_target['token_clean'])

# %%
df_target["sex"] = clf.predict(X_to_pred)
# Out:
# <ipython-input-34-4caf2268e829>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target["sex"] = clf.predict(X_to_pred)

# %%
df_target["age"] = gbdt.predict(X_to_pred)
# Out:
# <ipython-input-36-7480a37d0d08>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target["age"] = gbdt.predict(X_to_pred)

# %%
df_target
# Out:
#          ID                                           keywords        age sex  \
# 0         2  cecilia.gosselin:1;flash:1;ville:1;obseques:1;...  46.988544   M
# 1         3  p1_1697235:1;peut:1;jcms:1;les:1;acceptees:1;p...  48.907246   M
# 2         4                                  002lundu83vnndv:1  48.907246   F
# 3         5  high:3;patisserie:1;apple:3;tech:3;obseques:1;...  49.167906   M
# 4         6  disparition:1;vue:1;maelys:1;deuxieme:1;place:...  48.417619   F
# ...     ...                                                ...        ...  ..
# 9995  11353  faq:2;forum:1;force:1;acompte:2;majeure:1;affi...  47.147050   F
# 9996  11354             mouhcine:1;garcon:1;prenom:1;prenoms:1  48.907246   F
# 9997  11355  desprez:1;alain:1;obseques:1;pascal:1;cinema:1...  49.197891   F
# 9998  11356  utilisateurs:1;mineur:10;gold:10;jeu:10;strike...  48.907246   F
# 9999  11357                                             jobs:1  48.907246   M
#
#                                                    text  \
# 0     cecilia.gosselin flash ville obseques economie...
# 1     p1_1697235 peut jcms les acceptees pas benefic...
# 2                                      002lundu83vnndv
# 3     high high high patisserie apple apple apple te...
# 4     disparition vue maelys deuxieme place actu fla...
# ...                                                 ...
# 9995  faq faq forum force acompte acompte majeure af...
# 9996                    mouhcine garcon prenom prenoms
# 9997  desprez alain obseques pascal cinema dans unis...
# 9998  utilisateurs mineur mineur mineur mineur mineu...
# 9999                                              jobs
#
#                                             token_clean
# 0     flash ville obseque economie cinema chagrin un...
# 1                            assurance saisir vie fisc
# 2
# 3     high high high patisserie apple apple apple te...
# 4     disparition vue deuxieme place actu flash gard...
# ...                                                 ...
# 9995  faq faq forum force acompte acompte majeur loc...
# 9996                              garcon prenom prenom
# 9997          alain obseque pascal cinema unis chagrin
# 9998  utilisateur mineur mineur mineur mineur mineur...
# 9999                                              jobs
#
# [10000 rows x 6 columns]

# %%
df_target = df_target[["ID","age","sex"]]
df_target
# Out:
#          ID        age sex
# 0         2  46.988544   M
# 1         3  48.907246   M
# 2         4  48.907246   F
# 3         5  49.167906   M
# 4         6  48.417619   F
# ...     ...        ...  ..
# 9995  11353  47.147050   F
# 9996  11354  48.907246   F
# 9997  11355  49.197891   F
# 9998  11356  48.907246   F
# 9999  11357  48.907246   M
#
# [10000 rows x 3 columns]

# %%
df_target.to_csv('mlfinalresult.csv')
